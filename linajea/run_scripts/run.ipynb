# %% [markdown]
# Linajea Tracking Example
# =====================
#
#
# This example show all steps necessary to generate the final tracks, from training the network to finding the optimal hyperparameters on the validation data to computing the tracks on the test data.
#
# - train network
# - predict on validation data
# - grid search hyperparameters for ILP
#   - solve once per set of parameters
#   - evaluate once per set of parameters
#   - select set with fewest errors
# - predict on test data
# - solve on test data with optimal parameters
# - evaluate on test data

# %%
import logging
import os
import sys
import time
import types

import numpy as np
import pandas as pd

from linajea.config import (dump_config,
                            maybe_fix_config_paths_to_machine_and_load,
                            TrackingConfig)
from linajea.utils import (getNextInferenceData,
                           print_time)
import linajea.evaluation
from linajea.process_blockwise import (extract_edges_blockwise,
                                       predict_blockwise,
                                       solve_blockwise)
from linajea.training import train

# %%
logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s %(name)s %(levelname)-8s %(message)s')

# %% [markdown]
# Configuration
# --------------------
#
# All parameters to control the pipeline (e.g. model architecture, data augmentation, training parameters, ILP hyperparameters) are contained in a configuration file (in the TOML format https://toml.io)
#
# You can modify the `config_file` variable to point to the config file you would like to use. Make sure that the file paths contained in it point to the correct destination, for instance that they are adapted to your directory structure.

# %%
config_file = "config_example.toml"
config = maybe_fix_config_paths_to_machine_and_load(config_file)
config = TrackingConfig(**config)
#config = TrackingConfig.from_file(config)file
os.makedirs(config.general.setup_dir, exist_ok=True)

# %% [markdown]
# Training
# ------------
#
# To start training simply pass the configuration object to the train function. Make sure that the training data and parameters such as the number of iterations/setps are set correctly.
#
# To train until convergence will take from several hours to multiple days.

# %%
train(config)
# Out:
# 2022-06-24 06:01:51,511 linajea.training.torch_model INFO     initializing model..
# 2022-06-24 06:01:54,366 linajea.training.torch_model INFO     getting train/test output shape by running model twice
# 2022-06-24 06:01:58,372 linajea.training.torch_model INFO     test done
# 2022-06-24 06:01:58,813 linajea.training.torch_model INFO     train done
# 2022-06-24 06:01:58,819 linajea.training.train INFO     Model: UnetModelWrapper(
#   (unet_cell_ind): UNet(
#     (l_conv): ModuleList(
#       (0): ConvPass(
#         (layers): ModuleList(
#           (0): Conv4d(
#             (conv3d_layers): ModuleList(
#               (0): Conv3d(1, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (1): Conv3d(1, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (2): Conv3d(1, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             )
#           )
#           (1): ReLU()
#           (2): Conv4d(
#             (conv3d_layers): ModuleList(
#               (0): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (1): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (2): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             )
#           )
#           (3): ReLU()
#         )
#       )
#       (1): ConvPass(
#         (layers): ModuleList(
#           (0): Conv4d(
#             (conv3d_layers): ModuleList(
#               (0): Conv3d(12, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (1): Conv3d(12, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (2): Conv3d(12, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             )
#           )
#           (1): ReLU()
#           (2): Conv3d(48, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#       (2): ConvPass(
#         (layers): ModuleList(
#           (0): Conv3d(48, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(192, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#       (3): ConvPass(
#         (layers): ModuleList(
#           (0): Conv3d(192, 768, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(768, 768, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#     )
#     (l_down): ModuleList(
#       (0): Downsample(
#         (down): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): Downsample(
#         (down): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=0, dilation=1, ceil_mode=False)
#       )
#       (2): Downsample(
#         (down): MaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (r_up): ModuleList(
#       (0): ModuleList(
#         (0): Upsample(
#           (up): Sequential(
#             (0): ConvTranspose3d(48, 48, kernel_size=(1, 2, 2), stride=(1, 2, 2), groups=48)
#             (1): Conv3d(48, 12, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (activation): ReLU()
#         )
#         (1): Upsample(
#           (up): Sequential(
#             (0): ConvTranspose3d(192, 192, kernel_size=(1, 2, 2), stride=(1, 2, 2), groups=192)
#             (1): Conv3d(192, 48, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (activation): ReLU()
#         )
#         (2): Upsample(
#           (up): Sequential(
#             (0): ConvTranspose3d(768, 768, kernel_size=(2, 2, 2), stride=(2, 2, 2), groups=768)
#             (1): Conv3d(768, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (r_conv): ModuleList(
#       (0): ModuleList(
#         (0): ConvPass(
#           (layers): ModuleList(
#             (0): Conv3d(24, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#         (1): ConvPass(
#           (layers): ModuleList(
#             (0): Conv3d(96, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(48, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#         (2): ConvPass(
#           (layers): ModuleList(
#             (0): Conv3d(384, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(192, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (unet_par_vec): UNet(
#     (l_conv): ModuleList(
#       (0): ConvPass(
#         (layers): ModuleList(
#           (0): Conv4d(
#             (conv3d_layers): ModuleList(
#               (0): Conv3d(1, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (1): Conv3d(1, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (2): Conv3d(1, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             )
#           )
#           (1): ReLU()
#           (2): Conv4d(
#             (conv3d_layers): ModuleList(
#               (0): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (1): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (2): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             )
#           )
#           (3): ReLU()
#         )
#       )
#       (1): ConvPass(
#         (layers): ModuleList(
#           (0): Conv4d(
#             (conv3d_layers): ModuleList(
#               (0): Conv3d(12, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (1): Conv3d(12, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#               (2): Conv3d(12, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             )
#           )
#           (1): ReLU()
#           (2): Conv3d(48, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#       (2): ConvPass(
#         (layers): ModuleList(
#           (0): Conv3d(48, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(192, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#       (3): ConvPass(
#         (layers): ModuleList(
#           (0): Conv3d(192, 768, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (1): ReLU()
#           (2): Conv3d(768, 768, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#           (3): ReLU()
#         )
#       )
#     )
#     (l_down): ModuleList(
#       (0): Downsample(
#         (down): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=0, dilation=1, ceil_mode=False)
#       )
#       (1): Downsample(
#         (down): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=0, dilation=1, ceil_mode=False)
#       )
#       (2): Downsample(
#         (down): MaxPool3d(kernel_size=[2, 2, 2], stride=[2, 2, 2], padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (r_up): ModuleList(
#       (0): ModuleList(
#         (0): Upsample(
#           (up): Sequential(
#             (0): ConvTranspose3d(48, 48, kernel_size=(1, 2, 2), stride=(1, 2, 2), groups=48)
#             (1): Conv3d(48, 12, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (activation): ReLU()
#         )
#         (1): Upsample(
#           (up): Sequential(
#             (0): ConvTranspose3d(192, 192, kernel_size=(1, 2, 2), stride=(1, 2, 2), groups=192)
#             (1): Conv3d(192, 48, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (activation): ReLU()
#         )
#         (2): Upsample(
#           (up): Sequential(
#             (0): ConvTranspose3d(768, 768, kernel_size=(2, 2, 2), stride=(2, 2, 2), groups=768)
#             (1): Conv3d(768, 192, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (r_conv): ModuleList(
#       (0): ModuleList(
#         (0): ConvPass(
#           (layers): ModuleList(
#             (0): Conv3d(24, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(12, 12, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#         (1): ConvPass(
#           (layers): ModuleList(
#             (0): Conv3d(96, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(48, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#         (2): ConvPass(
#           (layers): ModuleList(
#             (0): Conv3d(384, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (1): ReLU()
#             (2): Conv3d(192, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#             (3): ReLU()
#           )
#         )
#       )
#     )
#   )
#   (cell_indicator_batched): ConvPass(
#     (layers): ModuleList(
#       (0): Conv3d(12, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (1): Sigmoid()
#     )
#   )
#   (parent_vectors_batched): ConvPass(
#     (layers): ModuleList(
#       (0): Conv3d(12, 3, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#     )
#   )
#   (nms): MaxPool3d(kernel_size=[3, 9, 9], stride=1, padding=0, dilation=1, ceil_mode=False)
# )
# 2022-06-24 06:01:58,821 linajea.training.train INFO     Center size: (2, 30, 52, 52)
# 2022-06-24 06:01:58,821 linajea.training.train INFO     Output size 1: (1, 40, 60, 60)
# 2022-06-24 06:01:58,821 linajea.training.train INFO     Voxel size: (1, 5, 1, 1)
# 2022-06-24 06:01:58,824 linajea.training.train INFO     REQUEST:
# 	RAW: ROI: [0:7, 0:200, 0:148, 0:148] (7, 200, 148, 148), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	CELL_INDICATOR: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	CELL_CENTER: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	ANCHOR: ROI: [3:4, 85:115, 48:100, 48:100] (1, 30, 52, 52), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	RAW_CROPPED: ROI: [3:4, 85:115, 48:100, 48:100] (1, 30, 52, 52), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	MAXIMA: ROI: [3:4, 85:115, 48:100, 48:100] (1, 30, 52, 52), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	PARENT_VECTORS: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	CELL_MASK: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	TRACKS: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), dtype: <class 'numpy.float32'>, directed: None, placeholder: False
# 	CENTER_TRACKS: ROI: [2:4, 85:115, 48:100, 48:100] (2, 30, 52, 52), dtype: <class 'numpy.float32'>, directed: None, placeholder: False
#
# 2022-06-24 06:01:58,826 linajea.training.train INFO     Snapshot request:
# 	RAW: ROI: [0:7, 0:200, 0:148, 0:148] (7, 200, 148, 148), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	PRED_CELL_INDICATOR: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	GRAD_CELL_INDICATOR: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	RAW_CROPPED: ROI: [3:4, 85:115, 48:100, 48:100] (1, 30, 52, 52), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	MAXIMA: ROI: [3:4, 85:115, 48:100, 48:100] (1, 30, 52, 52), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	PRED_PARENT_VECTORS: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
# 	GRAD_PARENT_VECTORS: ROI: [3:4, 80:120, 44:104, 44:104] (1, 40, 60, 60), voxel size: None, interpolatable: None, non-spatial: False, dtype: None, placeholder: False
#
# 2022-06-24 06:01:58,827 linajea.training.train INFO     loading data /nrs/funke/hirschp/mskcc_emb1 (val: False)
# 2022-06-24 06:01:58,843 linajea.training.train WARNING  Cannot find divisions_file in data_config, falling back to using tracks_file(usually ok unless they are not included and there is a separate file containing the divisions)
# 2022-06-24 06:01:58,844 linajea.training.train INFO     creating source: /nrs/funke/hirschp/mskcc_emb1/emb1.zarr (volumes/raw_nested, /nrs/funke/hirschp/mskcc_emb1/mskcc_emb1_tracks.txt, /nrs/funke/hirschp/mskcc_emb1/mskcc_emb1_tracks_daughters.txt), divisions?: True
# 2022-06-24 06:01:58,845 linajea.training.train INFO     limiting to roi: [0:50, 0:205, 0:512, 0:512] (50, 205, 512, 512)
# 2022-06-24 06:01:58,845 linajea.training.train INFO     minmax normalization 2000 7500
# 2022-06-24 06:01:58,846 linajea.training.train INFO     loading data /nrs/funke/hirschp/mskcc_emb (val: True)
# 2022-06-24 06:01:58,847 linajea.training.train WARNING  Cannot find divisions_file in data_config, falling back to using tracks_file(usually ok unless they are not included and there is a separate file containing the divisions)
# 2022-06-24 06:01:58,848 linajea.training.train INFO     creating source: /nrs/funke/hirschp/mskcc_emb/emb.zarr (volumes/raw_nested, /nrs/funke/hirschp/mskcc_emb/mskcc_emb_tracks.txt, /nrs/funke/hirschp/mskcc_emb/mskcc_emb_tracks_daughters.txt), divisions?: True
# 2022-06-24 06:01:58,848 linajea.training.train INFO     limiting to roi: [0:50, 0:205, 0:512, 0:512] (50, 205, 512, 512)
# 2022-06-24 06:01:58,849 linajea.training.train INFO     minmax normalization 2000 7500
# 2022-06-24 06:01:58,850 gunpowder.nodes.zoom_augment INFO     using zoom/scale augment 0.75 1.5 {RAW: 1} {}
# 2022-06-24 06:01:58,850 gunpowder.nodes.noise_augment INFO     using noise augment speckle {'var': [0.05]}
# 2022-06-24 06:01:58,850 gunpowder.nodes.noise_augment INFO     using noise augment s&p {'amount': [0.0001]}
# 2022-06-24 06:02:01,204 gunpowder.nodes.random_location INFO     requesting all CENTER_TRACKS points...
# 2022-06-24 06:02:02,503 gunpowder.nodes.random_location INFO     requesting all CENTER_TRACKS points...
# 2022-06-24 06:02:02,517 gunpowder.nodes.histogram_augment INFO     setting up histogram augment
# 2022-06-24 06:02:05,273 gunpowder.nodes.random_location INFO     requesting all CENTER_TRACKS points...
# 2022-06-24 06:02:06,722 gunpowder.nodes.random_location INFO     requesting all CENTER_TRACKS points...
# 2022-06-24 06:02:06,738 linajea.training.train INFO     Starting training...
# 2022-06-24 06:02:09,052 gunpowder.torch.nodes.train INFO     using auto mixed precision
# 2022-06-24 06:02:09,071 gunpowder.torch.nodes.train INFO     Resuming training from iteration 10
# 2022-06-24 06:02:09,073 gunpowder.torch.nodes.train INFO     Loading /groups/funke/home/hirschp/linajea_experiments/unet_setups/celegans_setups/experiments/mskc_test_1/train_net_checkpoint_10
# 2022-06-24 06:02:10,774 gunpowder.torch.nodes.train WARNING  no scaler state dict in checkpoint!
# 2022-06-24 06:02:10,776 gunpowder.torch.nodes.train INFO     Using device cuda
#   0%|          | 0/1 [00:04<?, ?it/s]/groups/funke/home/hirschp/tracking/gunpowder/gunpowder/torch/nodes/train.py:342: FutureWarning: Non-finite norm encountered in torch.nn.utils.clip_grad_norm_; continuing anyway. Note that the default behavior will change in a future release to error out if a non-finite total norm is encountered. At that point, setting error_if_nonfinite=false will be required to retain the old behavior.
#   total_norm_par_vec = torch.nn.utils.clip_grad_norm_(
# 2022-06-24 06:02:13,445 gunpowder.nodes.generic_train INFO     Train process: iteration=11 loss=5.192128 time=4.394
# 2022-06-24 06:02:13,450 gunpowder.nodes.snapshot INFO     saving to /groups/funke/home/hirschp/linajea_experiments/unet_setups/celegans_setups/experiments/mskc_test_1/snapshots/snapshot_11.hdf
# 2022-06-24 06:02:13,513 linajea.training.train INFO     Batch: iteration=10, time=6.772384
# 100%|██████████| 1/1 [00:06<00:00,  6.78s/it]

# %% [markdown]
# Inference/Tracking
# ---------------------------
#
# After the training is completed we first have to determine the optimal ILP hyperparameters.
# This is achieved by first creating the prediction on the validation data and then performing a grid search by solving the ILP and evaluating the results repeatedly.
#
# `getNextInferenceData` can be used to loop over the samples in the respective dataset, it returns a generator.
# If `validation` is set to `True` in `args` the validation data is used, otherwise the test data. Other details (e.g. which training checkpoint to use, which database to store the results in to use) are determined automatically based on the configuration file. Internally it adds an `inference_data` entry that is used by the postprocessing functions such as `*_blockwise` and `evaluate_setup`. This entry is updated automatically after each iteration to point to the correct sample.
#
# MongoDB is used to store the computed results. A `mongod` server has to be running before executing the remaining cells.
# See https://www.mongodb.com/docs/manual/administration/install-community/ for a guide on how to install it (Linux/Windows/MacOS)
# Alternatively you might want to create a singularity image (https://github.com/singularityhub/mongo). This can be used locally but will be necessary if you want to run the code on an HPC cluster and there is no server installed already.

# %%
args = types.SimpleNamespace(
        config=config_file, validation=True, val_param_id=None, param_id=None)

# %% [markdown]
# ### Predict Validation Data
#
# To predict the `cell_indicator` and `movement_vectors` on the validation data make sure that `args.validation` is set to `True`, then execute the next cell.
#
# Depending on the number of workers used (see config file) and the size of the data this can take a while.

# %%
args.validation = True
for inf_config in getNextInferenceData(args):
        predict_blockwise(inf_config)
# Out:
# 2022-06-24 09:41:11,157 linajea.utils.check_or_create_db INFO     linajea_celegans_20220624_134111: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb', '_id': ObjectId('62b5bef738f50c4aea2b1c6a')} (created)
# 2022-06-24 09:41:11,168 linajea.process_blockwise.predict_blockwise INFO     Following ROIs in world units:
# 2022-06-24 09:41:11,169 linajea.process_blockwise.predict_blockwise INFO     Input ROI       = [45:65, -85:315, -50:690, -50:690] (20, 400, 740, 740)
# 2022-06-24 09:41:11,170 linajea.process_blockwise.predict_blockwise INFO     Block read  ROI = [-3:4, -85:315, -50:210, -50:210] (7, 400, 260, 260)
# 2022-06-24 09:41:11,170 linajea.process_blockwise.predict_blockwise INFO     Block write ROI = [0:1, 0:230, 0:160, 0:160] (1, 230, 160, 160)
# 2022-06-24 09:41:11,171 linajea.process_blockwise.predict_blockwise INFO     Output ROI      = [48:62, 0:230, 0:640, 0:640] (14, 230, 640, 640)
# 2022-06-24 09:41:11,171 linajea.process_blockwise.predict_blockwise INFO     Starting block-wise processing...
# 2022-06-24 09:41:11,171 linajea.process_blockwise.predict_blockwise INFO     Sample: /nrs/funke/hirschp/mskcc_emb
# 2022-06-24 09:41:11,172 linajea.process_blockwise.predict_blockwise INFO     DB: linajea_celegans_20220624_134111
# 2022-06-24 09:41:11,233 daisy.scheduler INFO     Scheduling 224 tasks to completion.
# 2022-06-24 09:41:11,234 daisy.scheduler INFO     Max parallelism seems to be 224.
# 2022-06-24 09:41:11,236 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 0 processing, 224 pending
# 		ETA: unknown
# 2022-06-24 09:41:11,256 daisy.scheduler INFO     Launching workers for task BlockwiseTask
# 2022-06-24 09:41:11,286 linajea.process_blockwise.predict_blockwise INFO     Starting predict worker...
# 2022-06-24 09:41:11,288 linajea.process_blockwise.predict_blockwise INFO     Command: ['python -u /groups/funke/home/hirschp/tracking/linajea/linajea/prediction/predict.py --config tmp_configs/config_1656078071.1588793.toml']
# 2022-06-24 09:41:21,247 daisy.scheduler INFO
#
# 2022-06-24 09:41:21,249 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:41:31,259 daisy.scheduler INFO
#
# 2022-06-24 09:41:31,260 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:41:41,270 daisy.scheduler INFO
#
# 2022-06-24 09:41:41,271 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:41:51,282 daisy.scheduler INFO
#
# 2022-06-24 09:41:51,283 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:42:01,294 daisy.scheduler INFO
#
# 2022-06-24 09:42:01,295 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:42:11,305 daisy.scheduler INFO
#
# 2022-06-24 09:42:11,307 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:42:21,317 daisy.scheduler INFO
#
# 2022-06-24 09:42:21,318 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 1 processing, 223 pending
# 		ETA: unknown
# 2022-06-24 09:42:31,329 daisy.scheduler INFO
#
# 2022-06-24 09:42:31,330 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:42:41,340 daisy.scheduler INFO
#
# 2022-06-24 09:42:41,341 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:42:51,352 daisy.scheduler INFO
#
# 2022-06-24 09:42:51,353 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:43:01,363 daisy.scheduler INFO
#
# 2022-06-24 09:43:01,364 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:43:11,375 daisy.scheduler INFO
#
# 2022-06-24 09:43:11,376 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:43:21,387 daisy.scheduler INFO
#
# 2022-06-24 09:43:21,388 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:43:31,398 daisy.scheduler INFO
#
# 2022-06-24 09:43:31,399 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:43:41,402 daisy.scheduler INFO
#
# 2022-06-24 09:43:41,403 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:43:51,413 daisy.scheduler INFO
#
# 2022-06-24 09:43:51,414 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:44:01,425 daisy.scheduler INFO
#
# 2022-06-24 09:44:01,426 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:44:11,437 daisy.scheduler INFO
#
# 2022-06-24 09:44:11,438 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 2 processing, 222 pending
# 		ETA: unknown
# 2022-06-24 09:44:21,448 daisy.scheduler INFO
#
# 2022-06-24 09:44:21,449 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		3 finished (0 skipped, 3 succeeded, 0 failed), 2 processing, 219 pending
# 		ETA: unknown
# 2022-06-24 09:44:31,460 daisy.scheduler INFO
#
# 2022-06-24 09:44:31,461 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		8 finished (0 skipped, 8 succeeded, 0 failed), 2 processing, 214 pending
# 		ETA: unknown
# 2022-06-24 09:44:41,471 daisy.scheduler INFO
#
# 2022-06-24 09:44:41,472 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		13 finished (0 skipped, 13 succeeded, 0 failed), 2 processing, 209 pending
# 		ETA: unknown
# 2022-06-24 09:44:51,483 daisy.scheduler INFO
#
# 2022-06-24 09:44:51,484 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		18 finished (0 skipped, 18 succeeded, 0 failed), 2 processing, 204 pending
# 		ETA: unknown
# 2022-06-24 09:45:01,494 daisy.scheduler INFO
#
# 2022-06-24 09:45:01,495 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		23 finished (0 skipped, 23 succeeded, 0 failed), 1 processing, 200 pending
# 		ETA: unknown
# 2022-06-24 09:45:11,496 daisy.scheduler INFO
#
# 2022-06-24 09:45:11,497 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		28 finished (0 skipped, 28 succeeded, 0 failed), 1 processing, 195 pending
# 		ETA: 0:13:55.714286
# 2022-06-24 09:45:21,508 daisy.scheduler INFO
#
# 2022-06-24 09:45:21,509 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		33 finished (0 skipped, 33 succeeded, 0 failed), 1 processing, 190 pending
# 		ETA: 0:13:34.285714
# 2022-06-24 09:45:31,519 daisy.scheduler INFO
#
# 2022-06-24 09:45:31,520 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		37 finished (0 skipped, 37 succeeded, 0 failed), 2 processing, 185 pending
# 		ETA: 0:13:12.857143
# 2022-06-24 09:45:41,531 daisy.scheduler INFO
#
# 2022-06-24 09:45:41,532 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		42 finished (0 skipped, 42 succeeded, 0 failed), 2 processing, 180 pending
# 		ETA: 0:12:51.428571
# 2022-06-24 09:45:51,542 daisy.scheduler INFO
#
# 2022-06-24 09:45:51,543 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		47 finished (0 skipped, 47 succeeded, 0 failed), 2 processing, 175 pending
# 		ETA: 0:12:30
# 2022-06-24 09:46:01,553 daisy.scheduler INFO
#
# 2022-06-24 09:46:01,554 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		52 finished (0 skipped, 52 succeeded, 0 failed), 2 processing, 170 pending
# 		ETA: 0:12:08.571429
# 2022-06-24 09:46:11,564 daisy.scheduler INFO
#
# 2022-06-24 09:46:11,566 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		57 finished (0 skipped, 57 succeeded, 0 failed), 2 processing, 165 pending
# 		ETA: 0:11:47.142857
# 2022-06-24 09:46:21,576 daisy.scheduler INFO
#
# 2022-06-24 09:46:21,577 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		62 finished (0 skipped, 62 succeeded, 0 failed), 2 processing, 160 pending
# 		ETA: 0:11:25.714286
# 2022-06-24 09:46:31,587 daisy.scheduler INFO
#
# 2022-06-24 09:46:31,588 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		67 finished (0 skipped, 67 succeeded, 0 failed), 2 processing, 155 pending
# 		ETA: 0:11:04.285714
# 2022-06-24 09:46:41,599 daisy.scheduler INFO
#
# 2022-06-24 09:46:41,600 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		72 finished (0 skipped, 72 succeeded, 0 failed), 1 processing, 151 pending
# 		ETA: 0:10:47.142857
# 2022-06-24 09:46:51,607 daisy.scheduler INFO
#
# 2022-06-24 09:46:51,609 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		77 finished (0 skipped, 77 succeeded, 0 failed), 1 processing, 146 pending
# 		ETA: 0:10:25.714286
# 2022-06-24 09:47:01,617 daisy.scheduler INFO
#
# 2022-06-24 09:47:01,618 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		81 finished (0 skipped, 81 succeeded, 0 failed), 2 processing, 141 pending
# 		ETA: 0:10:04.285714
# 2022-06-24 09:47:11,619 daisy.scheduler INFO
#
# 2022-06-24 09:47:11,620 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		86 finished (0 skipped, 86 succeeded, 0 failed), 2 processing, 136 pending
# 		ETA: 0:04:41.379310
# 2022-06-24 09:47:21,621 daisy.scheduler INFO
#
# 2022-06-24 09:47:21,622 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		91 finished (0 skipped, 91 succeeded, 0 failed), 2 processing, 131 pending
# 		ETA: 0:04:31.034483
# 2022-06-24 09:47:31,632 daisy.scheduler INFO
#
# 2022-06-24 09:47:31,634 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		96 finished (0 skipped, 96 succeeded, 0 failed), 1 processing, 127 pending
# 		ETA: 0:04:22.758621
# 2022-06-24 09:47:41,639 daisy.scheduler INFO
#
# 2022-06-24 09:47:41,640 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		101 finished (0 skipped, 101 succeeded, 0 failed), 1 processing, 122 pending
# 		ETA: 0:04:12.413793
# 2022-06-24 09:47:51,651 daisy.scheduler INFO
#
# 2022-06-24 09:47:51,652 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		106 finished (0 skipped, 106 succeeded, 0 failed), 1 processing, 117 pending
# 		ETA: 0:04:02.068966
# 2022-06-24 09:48:01,662 daisy.scheduler INFO
#
# 2022-06-24 09:48:01,663 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		110 finished (0 skipped, 110 succeeded, 0 failed), 2 processing, 112 pending
# 		ETA: 0:03:51.724138
# 2022-06-24 09:48:11,674 daisy.scheduler INFO
#
# 2022-06-24 09:48:11,675 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		115 finished (0 skipped, 115 succeeded, 0 failed), 2 processing, 107 pending
# 		ETA: 0:03:41.379310
# 2022-06-24 09:48:21,685 daisy.scheduler INFO
#
# 2022-06-24 09:48:21,686 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		120 finished (0 skipped, 120 succeeded, 0 failed), 2 processing, 102 pending
# 		ETA: 0:03:31.034483
# 2022-06-24 09:48:31,689 daisy.scheduler INFO
#
# 2022-06-24 09:48:31,689 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		125 finished (0 skipped, 125 succeeded, 0 failed), 2 processing, 97 pending
# 		ETA: 0:03:20.689655
# 2022-06-24 09:48:41,690 daisy.scheduler INFO
#
# 2022-06-24 09:48:41,691 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		130 finished (0 skipped, 130 succeeded, 0 failed), 2 processing, 92 pending
# 		ETA: 0:03:10.344828
# 2022-06-24 09:48:51,692 daisy.scheduler INFO
#
# 2022-06-24 09:48:51,693 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		135 finished (0 skipped, 135 succeeded, 0 failed), 2 processing, 87 pending
# 		ETA: 0:03:00
# 2022-06-24 09:49:01,693 daisy.scheduler INFO
#
# 2022-06-24 09:49:01,694 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		140 finished (0 skipped, 140 succeeded, 0 failed), 1 processing, 83 pending
# 		ETA: 0:02:51.724138
# 2022-06-24 09:49:11,705 daisy.scheduler INFO
#
# 2022-06-24 09:49:11,706 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		145 finished (0 skipped, 145 succeeded, 0 failed), 1 processing, 78 pending
# 		ETA: 0:02:38.644068
# 2022-06-24 09:49:21,707 daisy.scheduler INFO
#
# 2022-06-24 09:49:21,707 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		150 finished (0 skipped, 150 succeeded, 0 failed), 1 processing, 73 pending
# 		ETA: 0:02:28.474576
# 2022-06-24 09:49:31,718 daisy.scheduler INFO
#
# 2022-06-24 09:49:31,719 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		154 finished (0 skipped, 154 succeeded, 0 failed), 2 processing, 68 pending
# 		ETA: 0:02:18.305085
# 2022-06-24 09:49:41,729 daisy.scheduler INFO
#
# 2022-06-24 09:49:41,730 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		159 finished (0 skipped, 159 succeeded, 0 failed), 2 processing, 63 pending
# 		ETA: 0:02:08.135593
# 2022-06-24 09:49:51,741 daisy.scheduler INFO
#
# 2022-06-24 09:49:51,742 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		164 finished (0 skipped, 164 succeeded, 0 failed), 2 processing, 58 pending
# 		ETA: 0:01:57.966102
# 2022-06-24 09:50:01,752 daisy.scheduler INFO
#
# 2022-06-24 09:50:01,753 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		169 finished (0 skipped, 169 succeeded, 0 failed), 2 processing, 53 pending
# 		ETA: 0:01:47.796610
# 2022-06-24 09:50:11,763 daisy.scheduler INFO
#
# 2022-06-24 09:50:11,764 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		174 finished (0 skipped, 174 succeeded, 0 failed), 2 processing, 48 pending
# 		ETA: 0:01:37.627119
# 2022-06-24 09:50:21,775 daisy.scheduler INFO
#
# 2022-06-24 09:50:21,776 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		179 finished (0 skipped, 179 succeeded, 0 failed), 2 processing, 43 pending
# 		ETA: 0:01:27.457627
# 2022-06-24 09:50:31,777 daisy.scheduler INFO
#
# 2022-06-24 09:50:31,778 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		184 finished (0 skipped, 184 succeeded, 0 failed), 2 processing, 38 pending
# 		ETA: 0:01:17.288136
# 2022-06-24 09:50:41,788 daisy.scheduler INFO
#
# 2022-06-24 09:50:41,790 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		189 finished (0 skipped, 189 succeeded, 0 failed), 1 processing, 34 pending
# 		ETA: 0:01:09.152542
# 2022-06-24 09:50:51,800 daisy.scheduler INFO
#
# 2022-06-24 09:50:51,801 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		194 finished (0 skipped, 194 succeeded, 0 failed), 1 processing, 29 pending
# 		ETA: 0:00:58.983051
# 2022-06-24 09:51:01,812 daisy.scheduler INFO
#
# 2022-06-24 09:51:01,813 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		199 finished (0 skipped, 199 succeeded, 0 failed), 1 processing, 24 pending
# 		ETA: 0:00:48.813559
# 2022-06-24 09:51:11,823 daisy.scheduler INFO
#
# 2022-06-24 09:51:11,824 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		203 finished (0 skipped, 203 succeeded, 0 failed), 2 processing, 19 pending
# 		ETA: 0:00:39.310345
# 2022-06-24 09:51:21,835 daisy.scheduler INFO
#
# 2022-06-24 09:51:21,836 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		208 finished (0 skipped, 208 succeeded, 0 failed), 2 processing, 14 pending
# 		ETA: 0:00:28.965517
# 2022-06-24 09:51:31,846 daisy.scheduler INFO
#
# 2022-06-24 09:51:31,847 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		213 finished (0 skipped, 213 succeeded, 0 failed), 2 processing, 9 pending
# 		ETA: 0:00:18.620690
# 2022-06-24 09:51:41,857 daisy.scheduler INFO
#
# 2022-06-24 09:51:41,859 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		218 finished (0 skipped, 218 succeeded, 0 failed), 2 processing, 4 pending
# 		ETA: 0:00:08.275862
# 2022-06-24 09:51:51,869 daisy.scheduler INFO
#
# 2022-06-24 09:51:51,870 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		223 finished (0 skipped, 223 succeeded, 0 failed), 1 processing, 0 pending
# 		ETA: 0:00:00
# 2022-06-24 09:52:01,881 daisy.scheduler INFO
#
# 2022-06-24 09:52:04,882 linajea.process_blockwise.predict_blockwise INFO     Predict worker finished
# 2022-06-24 09:52:04,902 daisy.scheduler INFO     Ran 224 tasks of which 224 succeeded, 0 were skipped, 0 were orphaned (failed dependencies), 0 tasks failed (0 failed check, 0 application errors, 0 network failures or app crashes)

# %% [markdown]
# ### Extract Edges Validation Data
#
# For each detected cell, look for neighboring cells in the next time frame and insert an edge candidate for each into the database.

# %%
for inf_config in getNextInferenceData(args):
        extract_edges_blockwise(inf_config)
# Out:
# 2022-06-24 10:01:13,456 linajea.utils.check_or_create_db INFO     linajea_celegans_20220624_134111: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb'} (accessed)
# 2022-06-24 10:01:13,462 linajea.process_blockwise.extract_edges_blockwise INFO     Following ROIs in world units:
# 2022-06-24 10:01:13,463 linajea.process_blockwise.extract_edges_blockwise INFO     Input ROI       = [47:62, -45:250, -45:557, -45:557] (15, 295, 602, 602)
# 2022-06-24 10:01:13,463 linajea.process_blockwise.extract_edges_blockwise INFO     Block read  ROI = [-1:5, -45:557, -45:557, -45:557] (6, 602, 602, 602)
# 2022-06-24 10:01:13,464 linajea.process_blockwise.extract_edges_blockwise INFO     Block write ROI = [0:5, 0:512, 0:512, 0:512] (5, 512, 512, 512)
# 2022-06-24 10:01:13,464 linajea.process_blockwise.extract_edges_blockwise INFO     Output ROI      = [48:62, 0:205, 0:512, 0:512] (14, 205, 512, 512)
# 2022-06-24 10:01:13,464 linajea.process_blockwise.extract_edges_blockwise INFO     Starting block-wise processing...
# 2022-06-24 10:01:13,464 linajea.process_blockwise.extract_edges_blockwise INFO     Sample: /nrs/funke/hirschp/mskcc_emb
# 2022-06-24 10:01:13,465 linajea.process_blockwise.extract_edges_blockwise INFO     DB: linajea_celegans_20220624_134111
# 2022-06-24 10:01:13,479 daisy.scheduler INFO     Scheduling 3 tasks to completion.
# 2022-06-24 10:01:13,479 daisy.scheduler INFO     Max parallelism seems to be 3.
# 2022-06-24 10:01:13,480 daisy.scheduler INFO
# 	BlockwiseTask processing 3 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 0 processing, 3 pending
# 		ETA: unknown
# 2022-06-24 10:01:13,496 daisy.scheduler INFO     Launching workers for task BlockwiseTask
# 2022-06-24 10:01:23,491 daisy.scheduler INFO
#
# 2022-06-24 10:01:23,493 daisy.scheduler INFO     Ran 3 tasks of which 3 succeeded, 0 were skipped, 0 were orphaned (failed dependencies), 0 tasks failed (0 failed check, 0 application errors, 0 network failures or app crashes)

# %% [markdown]
# ### Hyperparameter Grid Search
#
# #### Solve on Validation Data
#
# Make sure that `solve.grid_search` is set to `True`. The parameter sets to try are generated automatically.

# %%
config.solve.grid_search = True
args.config = dump_config(config)

# %%
import importlib
importlib.reload(linajea.process_blockwise)
parameters_ids = None
for inf_config in getNextInferenceData(args, is_solve=True):
        parameters_ids = linajea.process_blockwise.solve_blockwise(inf_config)
# Out:
# 2022-06-24 13:41:08,228 linajea.config.solve WARNING  overwriting explicit solve parameters with grid/random search parameters!
# 2022-06-24 13:41:09,161 linajea.utils.check_or_create_db INFO     linajea_celegans_20220624_134111: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb'} (accessed)
# 2022-06-24 13:41:09,186 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -21, 'selection_constant': 6, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:41:09,188 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -21, 'selection_constant': 6, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 9
# 2022-06-24 13:41:09,190 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:41:09,204 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 6
# 2022-06-24 13:41:09,206 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 12, 'weight_division': -11, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:41:09,222 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 12, 'weight_division': -11, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 52
# 2022-06-24 13:41:09,224 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 6, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:41:09,240 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 6, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 17
# 2022-06-24 13:41:09,242 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:41:09,257 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 43
# 2022-06-24 13:41:09,258 linajea.utils.candidate_database INFO     Resetting solution for parameter ids [9, 6, 52, 17, 43]
# 2022-06-24 13:41:09,287 linajea.utils.candidate_database INFO     Resetting soln for parameter_ids [9, 6, 52, 17, 43] in roi None took 0 seconds
# 2022-06-24 13:41:09,288 linajea.process_blockwise.solve_blockwise INFO     Solving in [48:62, -100:305, -100:612, -100:612] (14, 405, 712, 712)
# 2022-06-24 13:41:09,288 linajea.process_blockwise.solve_blockwise INFO     Sample: /nrs/funke/hirschp/mskcc_emb
# 2022-06-24 13:41:09,288 linajea.process_blockwise.solve_blockwise INFO     DB: linajea_celegans_20220624_134111
# 2022-06-24 13:41:09,557 linajea.process_blockwise.solve_blockwise INFO     Solving in block linajea_solving/1 with read ROI [48:67, -100:612, -100:612, -100:812] (19, 712, 712, 912) and write ROI [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# 2022-06-24 13:41:09,563 linajea.process_blockwise.solve_blockwise INFO     Write roi: [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# 2022-06-24 13:41:09,560 linajea.process_blockwise.solve_blockwise INFO     Block write roi: [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# linajea_solving ▶:   0%|          | 0/1 [00:00<?, ?blocks/s]
# 2022-06-24 13:41:09,561 linajea.process_blockwise.solve_blockwise INFO     Solution roi: [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:41:09,562 linajea.process_blockwise.solve_blockwise INFO     [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712) linajea_solving/1 with read ROI [48:67, -100:612, -100:612, -100:812] (19, 712, 712, 912) and write ROI [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# 2022-06-24 13:41:09,600 linajea.process_blockwise.solve_blockwise INFO     Reading graph with 393 nodes and 414 edges took 0.011182308197021484 seconds
# 2022-06-24 13:41:09,647 linajea.tracking.track INFO     Solving for key selected_9
# 2022-06-24 13:41:09,662 linajea.tracking.solver INFO     b'Optimal solution found'
# 2022-06-24 13:41:09,664 linajea.tracking.solver INFO     costs of solution: -4696.562564
# 2022-06-24 13:41:09,666 linajea.tracking.track INFO     Solving ILP took 0.01714777946472168 seconds
# 2022-06-24 13:41:09,672 linajea.tracking.track INFO     Solving for key selected_6
# 2022-06-24 13:41:09,688 linajea.tracking.solver INFO     b'Optimal solution found'
# 2022-06-24 13:41:09,689 linajea.tracking.solver INFO     costs of solution: -749.515936
# 2022-06-24 13:41:09,690 linajea.tracking.track INFO     Solving ILP took 0.017945528030395508 seconds
# 2022-06-24 13:41:09,696 linajea.tracking.track INFO     Solving for key selected_52
# 2022-06-24 13:41:09,710 linajea.tracking.solver INFO     b'Optimal solution found'
# 2022-06-24 13:41:09,710 linajea.tracking.solver INFO     costs of solution: -0.794531
# 2022-06-24 13:41:09,711 linajea.tracking.track INFO     Solving ILP took 0.01475834846496582 seconds
# 2022-06-24 13:41:09,717 linajea.tracking.track INFO     Solving for key selected_17
# 2022-06-24 13:41:09,731 linajea.tracking.solver INFO     b'Optimal solution found'
# 2022-06-24 13:41:09,731 linajea.tracking.solver INFO     costs of solution: -1920.244411
# 2022-06-24 13:41:09,733 linajea.tracking.track INFO     Solving ILP took 0.014906167984008789 seconds
# 2022-06-24 13:41:09,739 linajea.tracking.track INFO     Solving for key selected_43
# 2022-06-24 13:41:09,754 linajea.tracking.solver INFO     b'Optimal solution found'
# 2022-06-24 13:41:09,755 linajea.tracking.solver INFO     costs of solution: -749.515936
# 2022-06-24 13:41:09,756 linajea.tracking.track INFO     Solving ILP took 0.01688241958618164 seconds
# 2022-06-24 13:41:09,758 linajea.tracking.track INFO     Solving ILP for all parameters took 0.08164024353027344 seconds
# 2022-06-24 13:41:09,838 daisy.persistence.mongodb_graph_provider INFO     bulk writing key for 382 edges took 0.06541323661804199 seconds
# 2022-06-24 13:41:09,839 linajea.process_blockwise.solve_blockwise INFO     Updating 5 keys for 414 edges took 0.07689738273620605 seconds
# 2022-06-24 13:41:09,997 linajea.process_blockwise.solve_blockwise INFO     Finished solving
# Execution Summary
# -----------------
#
#   Task linajea_solving:
#
#     num blocks : 1
#     completed ✔: 1 (skipped 0)
#     failed    ✗: 0
#     orphaned  ∅: 0
#
#     all blocks processed successfully

# %% [markdown]
# #### Evaluate on Validation Data

# %%
import importlib
importlib.reload(linajea.evaluation)
args.param_ids = [9, 6, 52, 17, 43]

print(args.param_ids)
#args.param_ids = parameters_ids
for inf_config in getNextInferenceData(args, is_evaluate=True):
        t = linajea.evaluation.evaluate_setup(inf_config)
        print(t)
# Out:
# [9, 6, 52, 17, 43]
# [9, 6, 52, 17, 43] 9 6 [9, 6, 52, 17, 43]
# 2022-06-24 13:44:38,514 linajea.utils.check_or_create_db INFO     linajea_celegans_20220624_134111: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb'} (accessed)
# 2022-06-24 13:44:38,541 linajea.utils.get_next_inference_data INFO     getting params {'track_cost': 7, 'weight_node_score': -21, 'selection_constant': 6, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} (id: 9) from database linajea_celegans_20220624_134111 (sample: /nrs/funke/hirschp/mskcc_emb)
# 2022-06-24 13:44:38,541 linajea.utils.get_next_inference_data INFO     getting params {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} (id: 6) from database linajea_celegans_20220624_134111 (sample: /nrs/funke/hirschp/mskcc_emb)
# 2022-06-24 13:44:38,542 linajea.utils.get_next_inference_data INFO     getting params {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 12, 'weight_division': -11, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} (id: 52) from database linajea_celegans_20220624_134111 (sample: /nrs/funke/hirschp/mskcc_emb)
# 2022-06-24 13:44:38,542 linajea.utils.get_next_inference_data INFO     getting params {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 6, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} (id: 17) from database linajea_celegans_20220624_134111 (sample: /nrs/funke/hirschp/mskcc_emb)
# 2022-06-24 13:44:38,542 linajea.utils.get_next_inference_data INFO     getting params {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} (id: 43) from database linajea_celegans_20220624_134111 (sample: /nrs/funke/hirschp/mskcc_emb)
# 2022-06-24 13:44:39,444 linajea.utils.check_or_create_db INFO     linajea_celegans_20220624_134111: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb'} (accessed)
# 2022-06-24 13:44:39,445 linajea.evaluation.evaluate_setup INFO     roi None DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512))
# 2022-06-24 13:44:39,467 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -21, 'selection_constant': 6, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:44:39,469 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -21, 'selection_constant': 6, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 9
# 2022-06-24 13:44:39,487 linajea.evaluation.evaluate_setup INFO     Evaluating mskcc_emb in [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:44:39,507 linajea.evaluation.evaluate_setup INFO     Reading cells and edges in db linajea_celegans_20220624_134111 with parameter_id 9
# 2022-06-24 13:44:39,517 linajea.evaluation.evaluate_setup INFO     Read 305 cells and 279 edges in 0.009522438049316406 seconds
# 2022-06-24 13:44:39,527 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,528 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,528 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:39,529 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,529 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,530 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:39,530 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,531 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 50, track len: 1
# 2022-06-24 13:44:39,532 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,532 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,533 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,533 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,533 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,533 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,534 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,534 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,534 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:39,534 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,535 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,535 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,535 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,535 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,536 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:39,536 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,536 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,536 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,537 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,560 linajea.evaluation.evaluate_setup INFO     Reading ground truth cells and edges in db linajea_celegans_emb_fixed
# 2022-06-24 13:44:39,569 linajea.evaluation.evaluate_setup INFO     Read 282 cells and 258 edges in 0.008670330047607422 seconds
# 2022-06-24 13:44:39,572 linajea.evaluation.evaluate_setup INFO     Matching edges for parameters with id 9
# 2022-06-24 13:44:39,572 linajea.evaluation.evaluate INFO     Checking validity of reconstruction
# 2022-06-24 13:44:39,573 linajea.evaluation.evaluate INFO     Matching GT edges to REC edges...
# [SolveParametersMinimalConfig(track_cost=7, weight_node_score=-21, selection_constant=6, weight_division=-11, division_constant=6.0, weight_child=1.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=DataROIConfig(offset=[50, 0, 0, 0], shape=[10, 205, 512, 512]), feature_func='noop', val=True, tag=None), SolveParametersMinimalConfig(track_cost=7, weight_node_score=-13, selection_constant=9, weight_division=-8, division_constant=2.5, weight_child=2.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=DataROIConfig(offset=[50, 0, 0, 0], shape=[10, 205, 512, 512]), feature_func='noop', val=True, tag=None), SolveParametersMinimalConfig(track_cost=7, weight_node_score=-13, selection_constant=12, weight_division=-11, division_constant=2.5, weight_child=2.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=DataROIConfig(offset=[50, 0, 0, 0], shape=[10, 205, 512, 512]), feature_func='noop', val=True, tag=None), SolveParametersMinimalConfig(track_cost=7, weight_node_score=-13, selection_constant=6, weight_division=-8, division_constant=2.5, weight_child=1.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=DataROIConfig(offset=[50, 0, 0, 0], shape=[10, 205, 512, 512]), feature_func='noop', val=True, tag=None), SolveParametersMinimalConfig(track_cost=7, weight_node_score=-13, selection_constant=9, weight_division=-11, division_constant=6.0, weight_child=1.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=DataROIConfig(offset=[50, 0, 0, 0], shape=[10, 205, 512, 512]), feature_func='noop', val=True, tag=None)] 5
# 2022-06-24 13:44:39,850 linajea.evaluation.evaluate_setup INFO     roi DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512)) DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512))
# 2022-06-24 13:44:39,872 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:44:39,874 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 6
# 2022-06-24 13:44:39,891 linajea.evaluation.evaluate_setup INFO     Evaluating mskcc_emb in [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:44:39,910 linajea.evaluation.evaluate_setup INFO     Reading cells and edges in db linajea_celegans_20220624_134111 with parameter_id 6
# 2022-06-24 13:44:39,919 linajea.evaluation.evaluate_setup INFO     Read 304 cells and 278 edges in 0.007905960083007812 seconds
# 2022-06-24 13:44:39,928 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,929 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,930 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,930 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,931 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:39,932 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,932 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:39,933 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,933 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,933 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,934 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,934 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,935 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,935 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,935 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,935 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:39,936 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,936 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,936 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,936 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,937 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,937 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:39,937 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,937 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,938 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,938 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:39,962 linajea.evaluation.evaluate_setup INFO     Reading ground truth cells and edges in db linajea_celegans_emb_fixed
# 2022-06-24 13:44:39,970 linajea.evaluation.evaluate_setup INFO     Read 282 cells and 258 edges in 0.008071422576904297 seconds
# 2022-06-24 13:44:39,973 linajea.evaluation.evaluate_setup INFO     Matching edges for parameters with id 6
# 2022-06-24 13:44:39,974 linajea.evaluation.evaluate INFO     Checking validity of reconstruction
# 2022-06-24 13:44:39,974 linajea.evaluation.evaluate INFO     Matching GT edges to REC edges...
# <linajea.evaluation.report.Report object at 0x1552aab26e20>
# 2022-06-24 13:44:40,215 linajea.evaluation.evaluate_setup INFO     roi DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512)) DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512))
# 2022-06-24 13:44:40,235 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 12, 'weight_division': -11, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:44:40,237 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 12, 'weight_division': -11, 'division_constant': 2.5, 'weight_child': 2.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 52
# 2022-06-24 13:44:40,253 linajea.evaluation.evaluate_setup INFO     Evaluating mskcc_emb in [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:44:40,275 linajea.evaluation.evaluate_setup INFO     Reading cells and edges in db linajea_celegans_20220624_134111 with parameter_id 52
# 2022-06-24 13:44:40,282 linajea.evaluation.evaluate_setup INFO     Read 0 cells and 0 edges in 0.006875514984130859 seconds
# 2022-06-24 13:44:40,282 linajea.evaluation.evaluate_setup WARNING  No selected edges for parameters_id 52. Skipping
# 2022-06-24 13:44:40,284 linajea.evaluation.evaluate_setup INFO     roi DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512)) DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512))
# 2022-06-24 13:44:40,305 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 6, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:44:40,306 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 6, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 17
# 2022-06-24 13:44:40,324 linajea.evaluation.evaluate_setup INFO     Evaluating mskcc_emb in [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:44:40,344 linajea.evaluation.evaluate_setup INFO     Reading cells and edges in db linajea_celegans_20220624_134111 with parameter_id 17
# 2022-06-24 13:44:40,355 linajea.evaluation.evaluate_setup INFO     Read 305 cells and 279 edges in 0.009444236755371094 seconds
# 2022-06-24 13:44:40,364 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,366 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,366 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,367 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,368 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:40,368 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,369 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 50, track len: 1
# 2022-06-24 13:44:40,369 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:40,369 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,369 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,370 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,370 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,370 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,370 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,371 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,371 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,371 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:40,372 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,372 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,372 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,372 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,373 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,373 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:40,373 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,373 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,374 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,374 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,399 linajea.evaluation.evaluate_setup INFO     Reading ground truth cells and edges in db linajea_celegans_emb_fixed
# 2022-06-24 13:44:40,408 linajea.evaluation.evaluate_setup INFO     Read 282 cells and 258 edges in 0.00831151008605957 seconds
# 2022-06-24 13:44:40,411 linajea.evaluation.evaluate_setup INFO     Matching edges for parameters with id 17
# 2022-06-24 13:44:40,411 linajea.evaluation.evaluate INFO     Checking validity of reconstruction
# 2022-06-24 13:44:40,412 linajea.evaluation.evaluate INFO     Matching GT edges to REC edges...
# <linajea.evaluation.report.Report object at 0x155262fd5a00>
# False
# 2022-06-24 13:44:40,562 linajea.evaluation.match INFO     Done matching, found 233 matches and 0 edge fps
# 2022-06-24 13:44:40,562 linajea.evaluation.evaluate INFO     Done matching. Evaluating
# 2022-06-24 13:44:40,583 linajea.evaluation.evaluator INFO     Getting AEFTL and ERL
# 2022-06-24 13:44:40,593 linajea.evaluation.evaluator INFO     Getting perfect segments
# 2022-06-24 13:44:40,604 linajea.evaluation.evaluator INFO     track range 59 50
# 2022-06-24 13:44:40,607 linajea.evaluation.evaluator INFO     error free tracks: 27/30 0.9642857142857143
# 2022-06-24 13:44:40,616 linajea.evaluation.evaluate_setup INFO     Done evaluating results for 17. Saving results to mongo.
# 2022-06-24 13:44:40,617 linajea.evaluation.evaluate_setup INFO     Result summary: {'gt_tracks': 24, 'rec_tracks': 27, 'gt_matched_tracks': 24, 'rec_matched_tracks': 24, 'gt_edges': 234, 'rec_edges': 252, 'matched_edges': 233, 'gt_divisions': 4, 'rec_divisions': 4, 'fp_edges': 19, 'fn_edges': 0, 'identity_switches': 0, 'fp_divisions': 0, 'iso_fp_division': 0, 'fn_divisions': 0, 'iso_fn_division': 1, 'fn_divs_no_connections': 0, 'fn_divs_unconnected_child': 0, 'fn_divs_unconnected_parent': 1, 'precision': 0.9246031746031746, 'recall': 0.9957264957264957, 'f_score': 0.9588477366255145, 'aeftl': 9.708333333333334, 'erl': 10.106837606837606, 'correct_segments': {'1': (233, 234), '2': (205, 206), '3': (179, 180), '4': (153, 154), '5': (127,
'176': (0, 0), '177': (0, 0), '178': (0, 0), '179': (0, 0), '180': (0, 0), '181': (0, 0), '182': (0, 0), '183': (0, 0), '184': (0, 0), '185': (0, 0), '186': (0, 0), '187': (0, 0), '188': (0, 0), '189': (0, 0), '190': (0, 0), '191': (0, 0), '192': (0, 0), '193': (0, 0), '194': (0, 0), '195': (0, 0), '196': (0, 0), '197': (0, 0), '198': (0, 0), '199': (0, 0), '200': (0, 0), '201': (0, 0), '202': (0, 0), '203': (0, 0), '204': (0, 0), '205': (0, 0), '206': (0, 0), '207': (0, 0), '208': (0, 0), '209': (0, 0), '210': (0, 0), '211': (0, 0), '212': (0, 0), '213': (0, 0), '214': (0, 0), '215': (0, 0), '216': (0, 0), '217': (0, 0), '218': (0, 0), '219': (0, 0), '220': (0, 0), '221': (0, 0), '222': (0, 0), '223': (0, 0), '224': (0, 0), '225': (0, 0), '226': (0, 0), '227': (0, 0), '228': ...
# 2022-06-24 13:44:40,648 linajea.utils.candidate_database INFO     writing scores for {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 6, 'weight_division': -8, 'division_constant': 2.5, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} to {'param_id': 17, 'matching_threshold': 15, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'validation_score': False, 'window_size': 50, 'filter_short_tracklets_len': -1, 'ignore_one_off_div_errors': False, 'fn_div_count_unconnected_parent': True, 'sparse': False}
# 2022-06-24 13:44:40,652 linajea.evaluation.evaluate_setup INFO     roi DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512)) DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512))
# 2022-06-24 13:44:40,674 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:44:40,676 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': True, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 43
# 2022-06-24 13:44:40,693 linajea.evaluation.evaluate_setup INFO     Evaluating mskcc_emb in [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:44:40,713 linajea.evaluation.evaluate_setup INFO     Reading cells and edges in db linajea_celegans_20220624_134111 with parameter_id 43
# 2022-06-24 13:44:40,724 linajea.evaluation.evaluate_setup INFO     Read 304 cells and 278 edges in 0.010981321334838867 seconds
# 2022-06-24 13:44:40,734 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,735 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,736 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,737 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,737 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:40,738 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,738 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 18
# 2022-06-24 13:44:40,738 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,739 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,739 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,739 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,739 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,740 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,740 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,740 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,740 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:40,741 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,741 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,741 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,741 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,742 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,742 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 11
# 2022-06-24 13:44:40,742 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,743 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,743 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,743 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 59, track len: 10
# 2022-06-24 13:44:40,768 linajea.evaluation.evaluate_setup INFO     Reading ground truth cells and edges in db linajea_celegans_emb_fixed
# 2022-06-24 13:44:40,777 linajea.evaluation.evaluate_setup INFO     Read 282 cells and 258 edges in 0.008458852767944336 seconds
# 2022-06-24 13:44:40,780 linajea.evaluation.evaluate_setup INFO     Matching edges for parameters with id 43
# 2022-06-24 13:44:40,781 linajea.evaluation.evaluate INFO     Checking validity of reconstruction
# 2022-06-24 13:44:40,781 linajea.evaluation.evaluate INFO     Matching GT edges to REC edges...
# <linajea.evaluation.report.Report object at 0x1552a80941f0>
# 2022-06-24 13:44:40,931 linajea.evaluation.match INFO     Done matching, found 234 matches and 0 edge fps
# 2022-06-24 13:44:40,931 linajea.evaluation.evaluate INFO     Done matching. Evaluating
# 2022-06-24 13:44:40,953 linajea.evaluation.evaluator INFO     Getting AEFTL and ERL
# 2022-06-24 13:44:40,963 linajea.evaluation.evaluator INFO     Getting perfect segments
# 2022-06-24 13:44:40,973 linajea.evaluation.evaluator INFO     track range 59 50
# 2022-06-24 13:44:40,976 linajea.evaluation.evaluator INFO     error free tracks: 28/30 1.0
# 2022-06-24 13:44:40,985 linajea.evaluation.evaluate_setup INFO     Done evaluating results for 43. Saving results to mongo.
# 2022-06-24 13:44:40,986 linajea.evaluation.evaluate_setup INFO     Result summary: {'gt_tracks': 24, 'rec_tracks': 26, 'gt_matched_tracks': 24, 'rec_matched_tracks': 24, 'gt_edges': 234, 'rec_edges': 252, 'matched_edges': 234, 'gt_divisions': 4, 'rec_divisions': 4, 'fp_edges': 18, 'fn_edges': 0, 'identity_switches': 0, 'fp_divisions': 0, 'iso_fp_division': 0, 'fn_divisions': 0, 'iso_fn_division': 0, 'fn_divs_no_connections': 0, 'fn_divs_unconnected_child': 0, 'fn_divs_unconnected_parent': 0, 'precision': 0.9285714285714286, 'recall': 1.0, 'f_score': 0.962962962962963, 'aeftl': 9.75, 'erl': 10.247863247863247, 'correct_segments': {'1': (234, 234), '2': (206, 206), '3': (180, 180), '4': (154, 154), '5': (128, 128), '6': (102, 102), '7': (76, 76), '8': (50, 50), '9': (24, 24), '10': (0, 0), '11': (0, 0), '12': (0, 0), '13': (0, 0), '14': (0, 0), '15': (0, 0), '16': (0, 0), '17': (0, 0), '18
0, 0), '189': (0, 0), '190': (0, 0), '191': (0, 0), '192': (0, 0), '193': (0, 0), '194': (0, 0), '195': (0, 0), '196': (0, 0), '197': (0, 0), '198': (0, 0), '199': (0, 0), '200': (0, 0), '201': (0, 0), '202': (0, 0), '203': (0, 0), '204': (0, 0), '205': (0, 0), '206': (0, 0), '207': (0, 0), '208': (0, 0), '209': (0, 0), '210': (0, 0), '211': (0, 0), '212': (0, 0), '213': (0, 0), '214': (0, 0), '215': (0, 0), '216': (0, 0), '217': (0, 0), '218': (0, 0), '219': (0, 0), '220': (0, 0), '221': (0, 0), '222': (0, 0), '223': (0, 0), '224': (0, 0), '225': (0, 0), '226': (0, 0), '227': (0, 0), '228': (0, 0), '229': (0, 0), '230' ...
# 2022-06-24 13:44:41,017 linajea.utils.candidate_database INFO     writing scores for {'track_cost': 7, 'weight_node_score': -13, 'selection_constant': 9, 'weight_division': -11, 'division_constant': 6.0, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'feature_func': 'noop', 'val': True} to {'param_id': 43, 'matching_threshold': 15, 'roi': {'offset': [50, 0, 0, 0], 'shape': [10, 205, 512, 512]}, 'validation_score': False, 'window_size': 50, 'filter_short_tracklets_len': -1, 'ignore_one_off_div_errors': False, 'fn_div_count_unconnected_parent': True, 'sparse': False}
# <linajea.evaluation.report.Report object at 0x1552a80940a0>

# %% [markdown]
# ### Predict Test Data
#
# Now that we know which ILP hyperparameters to use we can predict the `cell_indicator` and `movement_vectors` on the test data and compute the tracks. Make sure that `args.validation` is set to `False` and `solve.grid_search` and `solve.random_search` are set to `False`.

# %%
config.solve.grid_search = False
config.solve.random_search = False
args.config = dump_config(config)
args.validation = False

# %%
for inf_config in getNextInferenceData(args):
        predict_blockwise(inf_config)
# Out:
# 2022-06-24 10:50:02,323 linajea.utils.check_or_create_db INFO     linajea_celegans_20220623_180937: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb3'} (accessed)
# 2022-06-24 10:50:02,331 linajea.process_blockwise.predict_blockwise INFO     Following ROIs in world units:
# 2022-06-24 10:50:02,331 linajea.process_blockwise.predict_blockwise INFO     Input ROI       = [45:65, -85:315, -50:690, -50:690] (20, 400, 740, 740)
# 2022-06-24 10:50:02,332 linajea.process_blockwise.predict_blockwise INFO     Block read  ROI = [-3:4, -85:315, -50:210, -50:210] (7, 400, 260, 260)
# 2022-06-24 10:50:02,332 linajea.process_blockwise.predict_blockwise INFO     Block write ROI = [0:1, 0:230, 0:160, 0:160] (1, 230, 160, 160)
# 2022-06-24 10:50:02,332 linajea.process_blockwise.predict_blockwise INFO     Output ROI      = [48:62, 0:230, 0:640, 0:640] (14, 230, 640, 640)
# 2022-06-24 10:50:02,332 linajea.process_blockwise.predict_blockwise INFO     Starting block-wise processing...
# 2022-06-24 10:50:02,333 linajea.process_blockwise.predict_blockwise INFO     Sample: /nrs/funke/hirschp/mskcc_emb3
# 2022-06-24 10:50:02,333 linajea.process_blockwise.predict_blockwise INFO     DB: linajea_celegans_20220623_180937
# 2022-06-24 10:50:02,388 daisy.scheduler INFO     Scheduling 224 tasks to completion.
# 2022-06-24 10:50:02,388 daisy.scheduler INFO     Max parallelism seems to be 224.
# 2022-06-24 10:50:02,389 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		0 finished (0 skipped, 0 succeeded, 0 failed), 0 processing, 224 pending
# 		ETA: unknown
# 2022-06-24 10:50:04,072 daisy.scheduler INFO     Launching workers for task BlockwiseTask
# 2022-06-24 10:50:04,099 linajea.process_blockwise.predict_blockwise INFO     Starting predict worker...
# 2022-06-24 10:50:04,103 linajea.process_blockwise.predict_blockwise INFO     Command: ['python -u /groups/funke/home/hirschp/tracking/linajea/linajea/prediction/predict.py --config tmp_configs/config_1656082202.324147.toml']
# 2022-06-24 10:50:12,400 daisy.scheduler INFO
#
# 2022-06-24 10:50:12,402 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:50:22,412 daisy.scheduler INFO
#
# 2022-06-24 10:50:22,413 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:50:32,423 daisy.scheduler INFO
#
# 2022-06-24 10:50:32,424 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:50:42,435 daisy.scheduler INFO
#
# 2022-06-24 10:50:42,436 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:50:52,446 daisy.scheduler INFO
#
# 2022-06-24 10:50:52,447 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:51:02,457 daisy.scheduler INFO
#
# 2022-06-24 10:51:02,458 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:51:12,469 daisy.scheduler INFO
#
# 2022-06-24 10:51:12,470 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:51:22,480 daisy.scheduler INFO
#
# 2022-06-24 10:51:22,481 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (0 aliases online)
# 		111 finished (111 skipped, 0 succeeded, 0 failed), 1 processing, 112 pending
# 		ETA: unknown
# 2022-06-24 10:51:32,492 daisy.scheduler INFO
#
# 2022-06-24 10:51:32,492 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:51:42,503 daisy.scheduler INFO
#
# 2022-06-24 10:51:42,504 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:51:52,514 daisy.scheduler INFO
#
# 2022-06-24 10:51:52,515 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:52:02,525 daisy.scheduler INFO
#
# 2022-06-24 10:52:02,526 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:52:12,537 daisy.scheduler INFO
#
# 2022-06-24 10:52:12,538 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:52:22,548 daisy.scheduler INFO
#
# 2022-06-24 10:52:22,549 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:52:32,559 daisy.scheduler INFO
#
# 2022-06-24 10:52:32,560 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:52:42,570 daisy.scheduler INFO
#
# 2022-06-24 10:52:42,571 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:52:52,582 daisy.scheduler INFO
#
# 2022-06-24 10:52:52,583 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:53:02,593 daisy.scheduler INFO
#
# 2022-06-24 10:53:02,594 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		122 finished (122 skipped, 0 succeeded, 0 failed), 2 processing, 100 pending
# 		ETA: unknown
# 2022-06-24 10:53:12,604 daisy.scheduler INFO
#
# 2022-06-24 10:53:12,605 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		126 finished (124 skipped, 2 succeeded, 0 failed), 2 processing, 96 pending
# 		ETA: unknown
# 2022-06-24 10:53:22,615 daisy.scheduler INFO
#
# 2022-06-24 10:53:22,616 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		141 finished (134 skipped, 7 succeeded, 0 failed), 1 processing, 82 pending
# 		ETA: unknown
# 2022-06-24 10:53:32,627 daisy.scheduler INFO
#
# 2022-06-24 10:53:32,627 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		150 finished (139 skipped, 11 succeeded, 0 failed), 2 processing, 72 pending
# 		ETA: unknown
# 2022-06-24 10:53:42,638 daisy.scheduler INFO
#
# 2022-06-24 10:53:42,639 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		157 finished (140 skipped, 17 succeeded, 0 failed), 1 processing, 66 pending
# 		ETA: unknown
# 2022-06-24 10:53:52,649 daisy.scheduler INFO
#
# 2022-06-24 10:53:52,650 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		164 finished (143 skipped, 21 succeeded, 0 failed), 2 processing, 58 pending
# 		ETA: unknown
# 2022-06-24 10:54:02,660 daisy.scheduler INFO
# 2022-06-24 10:54:02,661 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		169 finished (143 skipped, 26 succeeded, 0 failed), 2 processing, 53 pending
# 		ETA: 0:04:04.615385
# 2022-06-24 10:54:12,671 daisy.scheduler INFO
#
# 2022-06-24 10:54:12,672 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		174 finished (143 skipped, 31 succeeded, 0 failed), 2 processing, 48 pending
# 		ETA: 0:03:41.538462
# 2022-06-24 10:54:22,683 daisy.scheduler INFO
#
# 2022-06-24 10:54:22,683 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		180 finished (144 skipped, 36 succeeded, 0 failed), 2 processing, 42 pending
# 		ETA: 0:03:13.846154
# 2022-06-24 10:54:32,694 daisy.scheduler INFO
#
# 2022-06-24 10:54:32,695 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		185 finished (144 skipped, 41 succeeded, 0 failed), 2 processing, 37 pending
# 		ETA: 0:02:50.769231
# 2022-06-24 10:54:42,705 daisy.scheduler INFO
#
# 2022-06-24 10:54:42,706 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		190 finished (144 skipped, 46 succeeded, 0 failed), 1 processing, 33 pending
# 		ETA: 0:02:32.307692
# 2022-06-24 10:54:52,716 daisy.scheduler INFO
#
# 2022-06-24 10:54:52,717 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		195 finished (144 skipped, 51 succeeded, 0 failed), 1 processing, 28 pending
# 		ETA: 0:02:09.230769
# 2022-06-24 10:55:02,727 daisy.scheduler INFO
#
# 2022-06-24 10:55:02,728 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		200 finished (144 skipped, 56 succeeded, 0 failed), 1 processing, 23 pending
# 		ETA: 0:01:46.153846
# 2022-06-24 10:55:12,739 daisy.scheduler INFO
#
# 2022-06-24 10:55:12,739 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		205 finished (144 skipped, 61 succeeded, 0 failed), 1 processing, 18 pending
# 		ETA: 0:01:23.076923
# 2022-06-24 10:55:22,750 daisy.scheduler INFO
#
# 2022-06-24 10:55:22,751 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		209 finished (144 skipped, 65 succeeded, 0 failed), 2 processing, 13 pending
# 		ETA: 0:01:00
# 2022-06-24 10:55:32,761 daisy.scheduler INFO
#
# 2022-06-24 10:55:32,762 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		214 finished (144 skipped, 70 succeeded, 0 failed), 2 processing, 8 pending
# 		ETA: 0:00:36.923077
# 2022-06-24 10:55:42,772 daisy.scheduler INFO
#
# 2022-06-24 10:55:42,773 daisy.scheduler INFO
# 	BlockwiseTask processing 224 blocks with 1 workers (1 aliases online)
# 		219 finished (144 skipped, 75 succeeded, 0 failed), 2 processing, 3 pending
# 		ETA: 0:00:13.846154
# 2022-06-24 10:55:52,784 daisy.scheduler INFO
#
# 2022-06-24 10:55:57,224 linajea.process_blockwise.predict_blockwise INFO     Predict worker finished
# 2022-06-24 10:55:57,242 daisy.scheduler INFO     Ran 224 tasks of which 80 succeeded, 144 were skipped, 0 were orphaned (failed dependencies), 0 tasks failed (0 failed check, 0 application errors, 0 network failures or app crashes)

# %% [markdown]
# ### Solve on Test Data
#
# Then we can solve the ILP on the test data. We select the hyperparameters that resulted in the lowest overall number of errors on the validation data.

# %%
score_columns = ['fn_edges', 'identity_switches',
                 'fp_divisions', 'fn_divisions']
if not config.general.sparse:
    score_columns = ['fp_edges'] + score_columns

sort_by = "sum_errors"
results = {}
args.validation = True
for sample_idx, inf_config in enumerate(getNextInferenceData(args,
                                                             is_evaluate=True)):
    sample = inf_config.inference.data_source.datafile.filename
    print("getting results for:", sample)

    res = linajea.evaluation.get_results_sorted(
        inf_config,
        filter_params={"val": True},
        score_columns=score_columns,
        sort_by=sort_by)

    results[os.path.basename(sample)] = res.reset_index()
args.validation = False

results = pd.concat(list(results.values())).reset_index()
del results['param_id']
del results['_id']

by = [
    #"cell_cycle_key",
    #"filter_polar_bodies_key",
    "matching_threshold",
    "weight_node_score",
    "selection_constant",
    "track_cost",
    "weight_division",
    "division_constant",
    "weight_child",
    "weight_continuation",
    "weight_edge_score",
]
results = results.groupby(by, dropna=False, as_index=False).agg(
    lambda x: -1 if len(x) != sample_idx+1 else sum(x))

results = results[results.sum_errors != -1]
results.sort_values(sort_by, ascending=False, inplace=True)

#print(results)

config.solve.parameters = [config.solve.parameters[0]]
config.solve.parameters[0].weight_node_score = float(results.at[0, 'weight_node_score'])
config.solve.parameters[0].selection_constant = float(results.at[0, 'selection_constant'])
config.solve.parameters[0].track_cost = float(results.at[0, 'track_cost'])
config.solve.parameters[0].weight_edge_score = float(results.at[0, 'weight_edge_score'])
config.solve.parameters[0].weight_division = float(results.at[0, 'weight_division'])
config.solve.parameters[0].weight_child = float(results.at[0, 'weight_child'])
config.solve.parameters[0].weight_continuation = float(results.at[0, 'weight_continuation'])
print(config.solve.parameters[0], type(config.solve.parameters[0].weight_continuation))
args.config = dump_config(config)
# Out:
# 2022-06-27 11:04:01,266 linajea.utils.check_or_create_db INFO     linajea_celegans_20220624_134111: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb'} (accessed)
# 2022-06-27 11:04:01,267 linajea.evaluation.analyze_results INFO     checking db: linajea_celegans_20220624_134111
# 2022-06-27 11:04:01,295 linajea.utils.candidate_database INFO     Query: {'val': True, 'matching_threshold': 15, 'validation_score': False, 'window_size': 50, 'filter_short_tracklets_len': -1, 'ignore_one_off_div_errors': False, 'fn_div_count_unconnected_parent': True, 'sparse': False}
# 2022-06-27 11:04:01,297 linajea.utils.candidate_database INFO     Found 7 scores
# [SolveParametersMinimalConfig(track_cost=20.675083335777686, weight_node_score=-16.786125363574673, selection_constant=8.893522542354866, weight_division=-8.260920358667896, division_constant=5.9535746121046165, weight_child=1.003401421433546, weight_continuation=-1.0264581546174496, weight_edge_score=0.4254227576366175, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=None, feature_func='noop', val=False, tag=None)] 1
# getting results for: /nrs/funke/hirschp/mskcc_emb
# SolveParametersMinimalConfig(track_cost=7.0, weight_node_score=-21.0, selection_constant=6.0, weight_division=-11.0, division_constant=5.9535746121046165, weight_child=1.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=None, roi=None, feature_func='noop', val=False, tag=None) <class 'float'>
# /tmp/ipykernel_1479236/396560302.py:40: FutureWarning: Dropping invalid columns in DataFrameGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results = results.groupby(by, dropna=False, as_index=False).agg(

# %%
for inf_config in getNextInferenceData(args, is_solve=True):
        solve_blockwise(inf_config)
# Out:
# 2022-06-24 13:51:58,318 linajea.utils.check_or_create_db INFO     linajea_celegans_20220623_180937: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb3'} (accessed)
# 2022-06-24 13:51:58,344 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7.0, 'weight_node_score': -21.0, 'selection_constant': 6.0, 'weight_division': -11.0, 'division_constant': 5.9535746121046165, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': False, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:51:58,348 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7.0, 'weight_node_score': -21.0, 'selection_constant': 6.0, 'weight_division': -11.0, 'division_constant': 5.9535746121046165, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': False, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} not yet in collection, adding with id 3
# 2022-06-24 13:51:58,351 linajea.utils.candidate_database INFO     Resetting solution for parameter ids [3]
# 2022-06-24 13:51:58,368 linajea.utils.candidate_database INFO     Resetting soln for parameter_ids [3] in roi None took 0 seconds
# 2022-06-24 13:51:58,370 linajea.process_blockwise.solve_blockwise INFO     Solving in [48:62, -100:305, -100:612, -100:612] (14, 405, 712, 712)
# 2022-06-24 13:51:58,370 linajea.process_blockwise.solve_blockwise INFO     Sample: /nrs/funke/hirschp/mskcc_emb3
# 2022-06-24 13:51:58,371 linajea.process_blockwise.solve_blockwise INFO     DB: linajea_celegans_20220623_180937
# 2022-06-24 13:51:58,558 linajea.process_blockwise.solve_blockwise INFO     Solving in block linajea_solving/1 with read ROI [48:67, -100:612, -100:612, -100:812] (19, 712, 712, 912) and write ROI [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# linajea_solving ▶:   0%|          | 0/1 [00:00<?, ?blocks/s]
# 2022-06-24 13:51:58,561 linajea.process_blockwise.solve_blockwise INFO     Block write roi: [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# 2022-06-24 13:51:58,562 linajea.process_blockwise.solve_blockwise INFO     Solution roi: [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:51:58,562 linajea.process_blockwise.solve_blockwise INFO     [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712) linajea_solving/1 with read ROI [48:67, -100:612, -100:612, -100:812] (19, 712, 712, 912) and write ROI [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# 2022-06-24 13:51:58,563 linajea.process_blockwise.solve_blockwise INFO     Write roi: [50:65, 0:512, 0:512, 0:712] (15, 512, 512, 712)
# 2022-06-24 13:51:58,600 linajea.process_blockwise.solve_blockwise INFO     Reading graph with 426 nodes and 292 edges took 0.012198925018310547 seconds
# 2022-06-24 13:51:58,649 linajea.tracking.track INFO     Solving for key selected_3
# 2022-06-24 13:51:58,664 linajea.tracking.solver INFO     b'Optimal solution found'
# 2022-06-24 13:51:58,666 linajea.tracking.solver INFO     costs of solution: -3855.279642
# 2022-06-24 13:51:58,667 linajea.tracking.track INFO     Solving ILP took 0.017751216888427734 seconds
# 2022-06-24 13:51:58,670 linajea.tracking.track INFO     Solving ILP for all parameters took 0.017751216888427734 seconds
# 2022-06-24 13:51:58,726 daisy.persistence.mongodb_graph_provider INFO     bulk writing key for 250 edges took 0.04656338691711426 seconds
# 2022-06-24 13:51:58,727 linajea.process_blockwise.solve_blockwise INFO     Updating 1 keys for 292 edges took 0.05508017539978027 seconds
# 2022-06-24 13:51:58,788 linajea.process_blockwise.solve_blockwise INFO     Finished solving
# Execution Summary
# -----------------
#
#   Task linajea_solving:
#
#     num blocks : 1
#     completed ✔: 1 (skipped 0)
#     failed    ✗: 0
#     orphaned  ∅: 0
#
#     all blocks processed successfully

# %% [markdown]
# ### Evaluate on Test Data

# %%
for inf_config in getNextInferenceData(args, is_evaluate=True):
        linajea.evaluation.evaluate_setup(inf_config)
# Out:
# 2022-06-24 13:52:12,065 linajea.utils.check_or_create_db INFO     linajea_celegans_20220623_180937: {'setup_dir': 'mskc_test_1', 'iteration': 10, 'cell_score_threshold': 0.2, 'sample': 'mskcc_emb3'} (accessed)
# 2022-06-24 13:52:12,067 linajea.evaluation.evaluate_setup INFO     roi None DataROIConfig(offset=(50, 0, 0, 0), shape=(10, 205, 512, 512))
# 2022-06-24 13:52:12,087 linajea.utils.candidate_database INFO     Querying ID for parameters {'track_cost': 7.0, 'weight_node_score': -21.0, 'selection_constant': 6.0, 'weight_division': -11.0, 'division_constant': 5.9535746121046165, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': False, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}}
# 2022-06-24 13:52:12,090 linajea.utils.candidate_database INFO     Parameters {'track_cost': 7.0, 'weight_node_score': -21.0, 'selection_constant': 6.0, 'weight_division': -11.0, 'division_constant': 5.9535746121046165, 'weight_child': 1.0, 'weight_continuation': -1.0, 'weight_edge_score': 0.35, 'block_size': [15, 512, 512, 712], 'context': [2, 100, 100, 100], 'max_cell_move': 45, 'feature_func': 'noop', 'val': False, 'cell_cycle_key': {'$exists': False}, 'tag': {'$exists': False}} already in collection with id 3
# 2022-06-24 13:52:12,108 linajea.evaluation.evaluate_setup INFO     Evaluating mskcc_emb3 in [50:60, 0:205, 0:512, 0:512] (10, 205, 512, 512)
# 2022-06-24 13:52:12,130 linajea.evaluation.evaluate_setup INFO     Reading cells and edges in db linajea_celegans_20220623_180937 with parameter_id 3
# 2022-06-24 13:52:12,141 linajea.evaluation.evaluate_setup INFO     Read 234 cells and 205 edges in 0.010304927825927734 seconds
# 2022-06-24 13:52:12,150 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,150 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,151 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,151 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 9
# 2022-06-24 13:52:12,152 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,153 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 9
# 2022-06-24 13:52:12,154 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,154 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,155 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,155 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,156 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,156 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,156 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,157 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,157 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,157 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,157 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,158 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,158 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,158 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,158 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,159 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 10
# 2022-06-24 13:52:12,159 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,159 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,159 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,160 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,160 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,160 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 51, track len: 2
# 2022-06-24 13:52:12,160 linajea.evaluation.evaluate_setup INFO     track begin: 50, track end: 56, track len: 7
# 2022-06-24 13:52:12,186 linajea.evaluation.evaluate_setup INFO     Reading ground truth cells and edges in db linajea_celegans_emb3_fixed
# 2022-06-24 13:52:12,195 linajea.evaluation.evaluate_setup INFO     Read 274 cells and 250 edges in 0.008857250213623047 seconds
# 2022-06-24 13:52:12,199 linajea.evaluation.evaluate_setup INFO     Matching edges for parameters with id 3
# 2022-06-24 13:52:12,200 linajea.evaluation.evaluate INFO     Checking validity of reconstruction
# 2022-06-24 13:52:12,201 linajea.evaluation.evaluate INFO     Matching GT edges to REC edges...
# [SolveParametersMinimalConfig(track_cost=7.0, weight_node_score=-21.0, selection_constant=6.0, weight_division=-11.0, division_constant=5.9535746121046165, weight_child=1.0, weight_continuation=-1.0, weight_edge_score=0.35, cell_cycle_key=None, block_size=[15, 512, 512, 712], context=[2, 100, 100, 100], max_cell_move=45, roi=None, feature_func='noop', val=False, tag=None)] 1
# 2022-06-24 13:52:12,316 linajea.evaluation.match INFO     Done matching, found 147 matches and 0 edge fps
# 2022-06-24 13:52:12,316 linajea.evaluation.evaluate INFO     Done matching. Evaluating
# 2022-06-24 13:52:12,335 linajea.evaluation.evaluator INFO     Getting AEFTL and ERL
# 2022-06-24 13:52:12,342 linajea.evaluation.evaluator INFO     Getting perfect segments
# 2022-06-24 13:52:12,351 linajea.evaluation.evaluator INFO     track range 59 50
# 2022-06-24 13:52:12,352 linajea.evaluation.evaluator INFO     error free tracks: 0/0 0.0
# 2022-06-24 13:52:12,354 linajea.evaluation.analyze_candidates WARNING  Frame 57 not in candidate graph but in gt graph
